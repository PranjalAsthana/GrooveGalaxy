# %%
import pandas as pd
import numpy as np
import pickle as pkl

# %%
songs = pd.read_csv("spotify_millsongdata.csv")

# %%
songs
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
songs.shape
# Out:
# (57650, 4)

# %%
songs.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
songs.drop('link', axis=1).reset_index(drop=True)
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                                     text
# 0      Look at her face, it's a wonderful face  \r\nA...
# 1      Take it easy with me, please  \r\nTouch me gen...
# 2      I'll never know why I had to go  \r\nWhy I had...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# ...

# %%
songs = songs.sample(2000).drop('link', axis=1).reset_index(drop=True)
songs
# Out:
#                   artist                                        song  \
# 0                  Usher                       Lessons For The Lover
# 1        Louis Armstrong  Do You Know What Means To Miss New Orleans
# 2                   Rush                               Grand Designs
# 3             John Waite                        Dark Side Of The Sun
# 4                   Fun.                        All The Pretty Girls
# ...                  ...                                         ...
# 1995       Alison Krauss                         Take Me For Longing
# 1996     Alice In Chains                             A Little Bitter
# 1997         Fatboy Slim                  So In Love With You (Duke)
# 1998              Europe                            The Getaway Plan
# 1999  Olivia Newton-John                                Heartbreaker
#
#                                                    text
# 0     Turn the lights on  \r\n  \r\nHow could someon...
# ...

# %% [markdown]
# #Data Cleaning

# %%
songs['text'][0]
# Out:
# "Turn the lights on  \r\n  \r\nHow could someone hurt you but still make you feel so good?  \r\nHoller, scream and curse you and you stand there and let them do it  \r\nJust cause he gives you pain, that don't mean he ain't the one  \r\nFuck you out your brain you'll be smiling when he's done  \r\n  \r\nSo my advice would be no don't leave, don't go so easy, no  \r\nLet that argument turn you on  \r\nIt's worth it  \r\n  \r\nAnd these are the lessons learned by lovers  \r\nThese are the reasons we make love  \r\nThere's no exception, one day we gotta look each other in the eye  \r\nYou learn all these lessons when you're in love  \r\nA lesson for the lover, the lover  \r\nA lesson for the lover, the lover  \r\n  \r\nSo hard to imagine living life without them there  \r\n'Cause now you're so caught up in the passion  \r\nBut this shit is beyond compare, yeah  \r\nCause don't he make your heart beat, beat, beat like a drum  \r\nYou fought hard but think about how hard you come  \r\n  \
# ...

# %%
songs['text'].str.lower().replace(r'^\w\s',' ').replace(r'\n',' ', regex = True)
# Out:
# 0       turn the lights on  \r   \r how could someone ...
# 1       do you know what it means to miss new orleans ...
# 2       a to be  \r different degrees  \r   \r so much...
# 3       i looked over my shoulder  \r straight into yo...
# 4       all the pretty girls on a saturday night  \r  ...
#                               ...
# 1995    don't choose me because i am faithful.  \r don...
# 1996    how the mind does shout for rest  \r when the ...
# 1997    woman... i can't live,  \r live without you in...
# 1998    hey, i'm the voice in your head  \r a friend t...
# 1999    and there's no need to tell me i'm just wastin...
# Name: text, Length: 2000, dtype: object

# %%
songs['text'] = songs['text'].str.lower().replace(r'^\w\s',' ').replace(r'\n',' ', regex = True)

# %%
songs
# Out:
#                   artist                                        song  \
# 0                  Usher                       Lessons For The Lover
# 1        Louis Armstrong  Do You Know What Means To Miss New Orleans
# 2                   Rush                               Grand Designs
# 3             John Waite                        Dark Side Of The Sun
# 4                   Fun.                        All The Pretty Girls
# ...                  ...                                         ...
# 1995       Alison Krauss                         Take Me For Longing
# 1996     Alice In Chains                             A Little Bitter
# 1997         Fatboy Slim                  So In Love With You (Duke)
# 1998              Europe                            The Getaway Plan
# 1999  Olivia Newton-John                                Heartbreaker
#
#                                                    text
# 0     turn the lights on  \r   \r how could someone ...
# ...

# %%
#songs = songs.sample(20000)

# %% [markdown]
# #Vectorization

# %%
import nltk
nltk.download('punkt')
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stemmer = PorterStemmer()

# %%
def stemfunc(txt):
  token = nltk.word_tokenize(txt)
  a = [stemmer.stem(w) for w in token]
  return " ".join(a)

# %%
stemfunc("this is so beautiful it's amazing yet I just cant believe what I am seeing")
# Out:
# "thi is so beauti it 's amaz yet i just cant believ what i am see"

# %%
#songs['text'].apply(lambda x: stemfunc(x))

# %%
songs['text'] = songs['text'].apply(stemfunc)

# %%
songs
# Out:
#                   artist                                        song  \
# 0                  Usher                       Lessons For The Lover
# 1        Louis Armstrong  Do You Know What Means To Miss New Orleans
# 2                   Rush                               Grand Designs
# 3             John Waite                        Dark Side Of The Sun
# 4                   Fun.                        All The Pretty Girls
# ...                  ...                                         ...
# 1995       Alison Krauss                         Take Me For Longing
# 1996     Alice In Chains                             A Little Bitter
# 1997         Fatboy Slim                  So In Love With You (Duke)
# 1998              Europe                            The Getaway Plan
# 1999  Olivia Newton-John                                Heartbreaker
#
#                                                    text
# 0     turn the light on how could someon hurt you bu...
# ...

# %% [markdown]
# #TF-IDF Vectorisation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(analyzer='word', stop_words='english')

# %%
matrix = tfidf.fit_transform(songs['text'])

# %% [markdown]
# #Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(matrix)

# %%
similarity[0]
# Out:
# array([1.        , 0.0120405 , 0.01100593, ..., 0.04313214, 0.00914106,
#        0.0715655 ])

# %%
#songs[songs['song']=='On The Beach'].index[0]

# %%
songs
# Out:
#                   artist                                        song  \
# 0                  Usher                       Lessons For The Lover
# 1        Louis Armstrong  Do You Know What Means To Miss New Orleans
# 2                   Rush                               Grand Designs
# 3             John Waite                        Dark Side Of The Sun
# 4                   Fun.                        All The Pretty Girls
# ...                  ...                                         ...
# 1995       Alison Krauss                         Take Me For Longing
# 1996     Alice In Chains                             A Little Bitter
# 1997         Fatboy Slim                  So In Love With You (Duke)
# 1998              Europe                            The Getaway Plan
# 1999  Olivia Newton-John                                Heartbreaker
#
#                                                    text
# 0     turn the light on how could someon hurt you bu...
# ...

# %% [markdown]
# #Recommender Function

# %%
def recommender(song_name):
  idx = songs[songs['song']==song_name].index[0]
  distance = sorted(list(enumerate(similarity[idx])), reverse=True, key = lambda x:x[1])
  song = []
  for s in distance[1:6]:
    song.append(songs.iloc[s[0]].song)
  return song

# %%
#recommender("On The Beach")

# %% [markdown]
# #Dumping similarity matrix

# %%
pkl.dump(similarity,open("similaritymatrix.pkl","wb"))

# %%
pkl.dump(songs,open("songsdata.pkl","wb"))
